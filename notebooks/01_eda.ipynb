# %% [markdown]
# # 01 — Exploratory Data Analysis
# **Appetite Engineering** · Shawarma venue dataset
#
# Goals:
# - Understand price and rating distributions
# - Identify missing values and imputation candidates
# - Visualize geographic spread of venues
# - Check price–rating correlation (expected: weak)

# %%
# TODO: populate in lecture 4
import pandas as pd
import plotly.express as px
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.data import load_raw, clean, build_features

df_raw = load_raw()
df_raw.head()
